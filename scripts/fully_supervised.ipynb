# %% [markdown]
# ### 1. Revise config

# %%
import os
import yaml

config_dir = '/root/wj/EZ_CLIP/configs'
dataset = ['HARDVS', 'PAF', 'DVS128Gesture', 'SeAct']
config_file_templates = ['{}_train.yaml', '{}_testing.yaml']

for d in dataset:
    for config_template in config_file_templates:
        config_file = os.path.join(config_dir, d, config_template.format(d))
        print(config_file)
        # Read existing YAML content
        if os.path.exists(config_file):
            with open(config_file, 'r') as infile:
                config_data = yaml.safe_load(infile) or {}
        else:
            config_data = {}
        # basic setting
        config_data['network']['type'] = 'full_supervised' 
        config_data['weight_save_dir'] = '/root/autodl-tmp/SAMPLE'
        config_data['training_name'] = f"{config_template.format(d).replace('.yaml', '')}_full_supervised"
        config_data['network']['sim_header'] = 'Transf'
        config_data['mm_prompt']['CTX_INIT'] = 'a human action of'

        config_data['T_Adapter'] = False
        # time prompt
        config_data['prompt']['use']= True
        config_data['prompt']['DEEP']= True
        # mm prompt
        config_data['mm_prompt']['use'] = True
        config_data['mm_prompt']['N_CTX']= 2
        config_data['mm_prompt']['PROMPT_DEPTH']= 9

        # Print log directory
        logdir = os.path.join(
            config_data["weight_save_dir"],
            config_data["network"]["type"],
            config_data["network"].get("arch", "unknown_arch"),
            config_data["data"].get("dataset", d),
            config_data['training_name']
        )
        print(f"{config_template.format(d)} logdir: {logdir}")
        if config_template == '{}_testing.yaml':
            config_data['pretrain'] = os.path.join(logdir.replace('_testing','_train'), 'model_best.pt')

        
        # Write back to YAML file
        with open(config_file, 'w') as outfile:
            yaml.dump(config_data, outfile, default_flow_style=False)
# Out:
# /root/wj/EZ_CLIP/configs/HARDVS/HARDVS_train.yaml
# HARDVS_train.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/HARDVS/HARDVS_train_full_supervised
# /root/wj/EZ_CLIP/configs/HARDVS/HARDVS_testing.yaml
# HARDVS_testing.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/HARDVS/HARDVS_testing_full_supervised
# /root/wj/EZ_CLIP/configs/PAF/PAF_train.yaml
# PAF_train.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/PAF/PAF_train_full_supervised
# /root/wj/EZ_CLIP/configs/PAF/PAF_testing.yaml
# PAF_testing.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/PAF/PAF_testing_full_supervised
# /root/wj/EZ_CLIP/configs/DVS128Gesture/DVS128Gesture_train.yaml
# DVS128Gesture_train.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/DVS128Gesture/DVS128Gesture_train_full_supervised
# /root/wj/EZ_CLIP/configs/DVS128Gesture/DVS128Gesture_testing.yaml
# DVS128Gesture_testing.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/DVS128Gesture/DVS128Gesture_testing_full_supervised
# /root/wj/EZ_CLIP/configs/SeAct/SeAct_train.yaml
# SeAct_train.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/SeAct/SeAct_train_full_supervised
# /root/wj/EZ_CLIP/configs/SeAct/SeAct_testing.yaml
# SeAct_testing.yaml logdir: /root/autodl-tmp/SAMPLE/full_supervised/ViT-B/16/SeAct/SeAct_testing_full_supervised

# %% [markdown]
# ### 2. Training

# %%
for d in dataset:
    os.system(f'echo /root/wj/EZ_CLIP/scripts/train_{d}_full_.sh')

# %%
os.system("python test_SAMPLE.py --config /root/wj/EZ_CLIP/configs/SeAct/SeAct_testing.yaml")

# %%
os.system("python train_SAMPLE.py --config /root/wj/EZ_CLIP/configs/PAF/PAF_train.yaml")

# %%
os.system("python test_SAMPLE.py --config /root/wj/EZ_CLIP/configs/PAF/PAF_testing.yaml")

# %%
os.system("python train_SAMPLE.py --config /root/wj/EZ_CLIP/configs/HARDVS/HARDVS_train.yaml")

# %%
os.system("python test_SAMPLE.py --config /root/wj/EZ_CLIP/configs/HARDVS/HARDVS_testing.yaml")

# %%
os.system("python train_SAMPLE.py --config /root/wj/EZ_CLIP/configs/DVS128Gesture/DVS128Gesture_train.yaml")

# %%
os.system("python test_SAMPLE.py --config /root/wj/EZ_CLIP/configs/DVS128Gesture/DVS128Gesture_testing.yaml")
